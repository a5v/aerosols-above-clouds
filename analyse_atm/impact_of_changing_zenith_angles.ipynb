# %% [markdown]
# # Changing Viewing and Solar Zenith Angle

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %% [markdown]
# ## Nadir

# %%
df_cloud_atm = pd.read_csv("../create_atm/atmospheres/cloud_atm_1-2_long.csv", header = None, index_col = 0)

# %%
N_cloud_atm = int(df_cloud_atm.shape[1]/2)
effr_cloud = [0.1,0.5,1,2,4,8,10,16,20,32]

fig, ax = plt.subplots()

low_effr = 4

for i in range(low_effr, N_cloud_atm):
    plt.plot(df_cloud_atm[i+1], df_cloud_atm[i+1+N_cloud_atm])
# plt.plot(df_cloud_atm[5], df_cloud_atm[11])
# plt.plot(df_cloud_atm[6], df_cloud_atm[12])

plt.legend(effr_cloud[low_effr:], title='effective radius of cloud ($\mu$m)')
plt.xlabel('Reflection Function ($\lambda$ = 0.56 $\mu$m)')
plt.ylabel('Reflection Function ($\lambda$  = 1.59 $\mu$m)')
plt.title('$\mu_{0}$ = 1, $\mu$ = 1')

# for i in range(N_dTau_cloud):
#     x = df2_cloud_atm[dTau_range_cloud[i]][low_effr:N_cloud_atm]
#     y = df2_cloud_atm[dTau_range_cloud[i]][N_cloud_atm+low_effr:2*N_cloud_atm]
    
#     plt.plot(x,y, color = 'k')
# Out:
# Text(0.5, 1.0, '$\\mu_{0}$ = 1, $\\mu$ = 1')

# %% [markdown]
# ## Changing Solar Zenith Angle

# %% [markdown]
# > solar zenith angle = 30

# %%
df_sol_30 = pd.read_csv("../create_atm/atmospheres/cloud_atm_1-2_sol_30.csv", header = None, index_col = 0)

# %%
#df_sol_30

# %%
fig, ax = plt.subplots()

low_effr = 4

for i in range(low_effr, N_cloud_atm):
    plt.plot(df_sol_30[i+1], df_sol_30[i+1+N_cloud_atm])
# plt.plot(df_cloud_atm[5], df_cloud_atm[11])
# plt.plot(df_cloud_atm[6], df_cloud_atm[12])

plt.legend(effr_cloud[low_effr:], title='effective radius of cloud ($\mu$m)')
plt.xlabel('Reflection Function ($\lambda$ = 0.56 $\mu$m)')
plt.ylabel('Reflection Function ($\lambda$  = 1.59 $\mu$m)')
plt.title('$\mu_{0}$ = sqrt(3)/2, $\mu$ = 1')
# Out:
# Text(0.5, 1.0, '$\\mu_{0}$ = sqrt(3)/2, $\\mu$ = 1')

# %% [markdown]
# > solar zenith angle = 60

# %%
df_sol_60 = pd.read_csv("../create_atm/atmospheres/cloud_atm_1-2_sol_60.csv", header = None, index_col = 0)

# %%
fig, ax = plt.subplots()

low_effr = 4

for i in range(low_effr, N_cloud_atm):
    plt.plot(df_sol_60[i+1], df_sol_60[i+1+N_cloud_atm])
# plt.plot(df_cloud_atm[5], df_cloud_atm[11])
# plt.plot(df_cloud_atm[6], df_cloud_atm[12])

plt.legend(effr_cloud[low_effr:], title='effective radius of cloud ($\mu$m)')
plt.xlabel('Reflection Function ($\lambda$ = 0.56 $\mu$m)')
plt.ylabel('Reflection Function ($\lambda$  = 1.59 $\mu$m)')
plt.title('$\mu_{0}$ = 0.5, $\mu$ = 1')
# Out:
# Text(0.5, 1.0, '$\\mu_{0}$ = 0.5, $\\mu$ = 1')

# %% [markdown]
# ## Changing Viewing Zenith Angle

# %% [markdown]
# > viewing zenith angle = 30

# %%
df_view_30 = pd.read_csv("../create_atm/atmospheres/cloud_atm_1-2_view_30.csv", header = None, index_col = 0)

# %%
fig, ax = plt.subplots()

low_effr = 4

for i in range(low_effr, N_cloud_atm):
    plt.plot(df_view_30[i+1], df_view_30[i+1+N_cloud_atm])
# plt.plot(df_cloud_atm[5], df_cloud_atm[11])
# plt.plot(df_cloud_atm[6], df_cloud_atm[12])

plt.legend(effr_cloud[low_effr:], title='effective radius of cloud ($\mu$m)')
plt.xlabel('Reflection Function ($\lambda$ = 0.56 $\mu$m)')
plt.ylabel('Reflection Function ($\lambda$  = 1.59 $\mu$m)')
plt.title('$\mu_{0}$ = 1, $\mu$ = sqrt(3)/2')
# Out:
# Text(0.5, 1.0, '$\\mu_{0}$ = 1, $\\mu$ = sqrt(3)/2')

# %% [markdown]
# > viewing zenith angle = 60

# %%
df_view_60 = pd.read_csv("../create_atm/atmospheres/cloud_atm_1-2_view_60.csv", header = None, index_col = 0)

# %%
fig, ax = plt.subplots()

low_effr = 4

for i in range(low_effr, N_cloud_atm):
    plt.plot(df_view_60[i+1], df_view_60[i+1+N_cloud_atm])
# plt.plot(df_cloud_atm[5], df_cloud_atm[11])
# plt.plot(df_cloud_atm[6], df_cloud_atm[12])

plt.legend(effr_cloud[low_effr:], title='effective radius of cloud ($\mu$m)')
plt.xlabel('Reflection Function ($\lambda$ = 0.56 $\mu$m)')
plt.ylabel('Reflection Function ($\lambda$  = 1.59 $\mu$m)')
plt.title('$\mu_{0}$ = 1, $\mu$ = 0.5')
# Out:
# Text(0.5, 1.0, '$\\mu_{0}$ = 1, $\\mu$ = 0.5')
